# %%
import pandas as pd
melb_df = pd.read_csv('data/melb_data_fe.csv')
melb_df['Date'] = pd.to_datetime(melb_df['Date'])
def get_quarter(month):
    if 1 <= month <= 3:
        return 'First'
    elif 4 <= month <= 6:
        return 'Second'
    elif 7 <= month <= 9:
        return 'Third'
    elif 10 < month <= 12:
        return 'Forth'
    else:
        return 'else'
melb_df['Quarter'] = melb_df['Date'].dt.month.apply(get_quarter)
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car'] # список столбцов, которые мы не берём во внимание
max_unique_count = 150 # задаём максимальное число уникальных категорий
for col in melb_df.columns: # цикл по именам столбцов
    if melb_df[col].nunique() < max_unique_count and col not in cols_to_exclude: # проверяем условие
        melb_df[col] = melb_df[col].astype('category')
melb_df.sort_values(by='AreaRatio', ascending=False, ignore_index=True)
mask1 = melb_df['Rooms'] > 2
mask2 = melb_df['Type'] == 'townhouse'
melb_df[mask1 & mask2].sort_values(by=['Rooms', 'MeanRoomsSquare'], ascending=[True, False], ignore_index=True).loc[10:20, ['Rooms', 'MeanRoomsSquare', 'Price']]
melb_df.groupby('Regionname')['Distance'].min().sort_values(ascending=False)
melb_df.groupby('MonthSale')['Price'].agg('describe').sort_values(by='count', ascending=False)
melb_df.groupby('Regionname')['SellerG'].agg(
                    ['nunique', set]
)
melb_df.groupby('Rooms')['Price'].mean().sort_values(ascending=False)
melb_df.groupby('Regionname')['Lattitude'].std().sort_values()
date1 = pd.to_datetime('2017-05-01')
date2 = pd.to_datetime('2017-09-01')
mask = (date1 <= melb_df['Date']) & (melb_df['Date'] <= date2)
melb_df[mask].groupby('SellerG')['Price'].sum().sort_values(ascending=False)
# Out:
# SellerG
# Jellis           414121833.0
# Nelson           379767500.0
# other            365038432.0
# Barry            296723050.0
# hockingstuart    282834310.0
# Marshall         253957888.0
# Ray              249572986.0
# Buxton           219104000.0
# Biggin           110429500.0
# Fletchers        108847700.0
# Noel              88129800.0
# Woodards          85977500.0
# Greg              85621000.0
# McGrath           78386500.0
# Harcourts         68720250.0
# Jas               59281600.0
# Brad              55955000.0
# RT                50498000.0
# Kay               48569500.0
# Miles             47582000.0
# YPA               46354350.0
# Hodges            43231000.0
# Gary              39138400.0
# Sweeney           36882750.0
# Stockdale         35409800.0
# Raine             30687700.0
# RW                29261000.0
# Village           26473000.0
# HAR               25568000.0
# O'Brien           23855508.0
# Purplebricks      23401000.0
# ...

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# Out:
# Type          house     townhouse          unit
# Rooms
# 1      8.668655e+05  5.927045e+05  3.899289e+05
# 2      1.017238e+06  7.101585e+05  6.104905e+05
# 3      1.109233e+06  9.847087e+05  8.505963e+05
# 4      1.462283e+06  1.217092e+06  1.037476e+06
# 5      1.877327e+06  1.035000e+06           NaN
# 6      1.869508e+06           NaN  5.200000e+05
# 7      1.920700e+06           NaN           NaN
# 8      1.510286e+06           NaN  2.250000e+06
# 10     9.000000e+05           NaN           NaN

# %%
melb_df.pivot_table(
values='Price',
index='Rooms',
columns='Type',
fill_value=0
).round()
# Out:
# Type       house  townhouse       unit
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        0.0
# 6      1869508.0        0.0   520000.0
# 7      1920700.0        0.0        0.0
# 8      1510286.0        0.0  2250000.0
# 10      900000.0        0.0        0.0

# %%
melb_df.pivot_table(
values='Price',
index='Regionname',
columns='Weekend',
aggfunc='count'
).round()
# Out:
# Weekend                        0     1
# Regionname
# Eastern Metropolitan         447  1024
# Eastern Victoria              13    40
# Northern Metropolitan       1258  2632
# Northern Victoria             11    30
# South-Eastern Metropolitan   123   327
# Southern Metropolitan       1534  3161
# Western Metropolitan         960  1988
# Western Victoria               8    24

# %%
melb_df.pivot_table(
values='Landsize',
index='Regionname',
columns='Type',
aggfunc=['median', 'mean'],
fill_value=0
).round()
# Out:
#                            median                   mean
# Type                        house townhouse unit   house townhouse   unit
# Regionname
# Eastern Metropolitan        674.0     234.0  203   717.0     269.0  330.0
# Eastern Victoria            843.0       0.0  230  3109.0       0.0  295.0
# Northern Metropolitan       460.0     134.0    0   619.0     317.0  495.0
# Northern Victoria           724.0       0.0    0  3355.0       0.0    0.0
# South-Eastern Metropolitan  630.0     240.0  199   664.0     212.0  358.0
# Southern Metropolitan       586.0     246.0    0   570.0     279.0  466.0
# Western Metropolitan        531.0     198.0   62   508.0     245.0  558.0
# Western Victoria            600.0       0.0    0   656.0       0.0    0.0

# %%
melb_df.pivot_table(
    values='Price',
    index=['Method','Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
)
# Out:
# Regionname        Eastern Metropolitan  Eastern Victoria  \
# Method Type
# PI     house                   1244000            780000
#        townhouse                760000                 0
#        unit                     650000                 0
# S      house                   1127000            675000
#        townhouse                828000                 0
#        unit                     645750            492000
# SA     house                    932500            950000
#        townhouse                807500                 0
#        unit                          0                 0
# SP     house                   1050000            672500
#        townhouse                910000                 0
#        unit                     515000            400000
# VB     house                   1100000            712500
#        townhouse                892500                 0
#        unit                     500000                 0
#
# ...

# %%
pivot = melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
pivot.columns
# Out:
# MultiIndex([('median',     'house'),
#             ('median', 'townhouse'),
#             ('median',      'unit'),
#             (  'mean',     'house'),
#             (  'mean', 'townhouse'),
#             (  'mean',      'unit')],
#            names=[None, 'Type'])

# %%
display(pivot['mean','unit'])
# Out:
# Regionname
# Eastern Metropolitan          330.444444
# Eastern Victoria              295.333333
# Northern Metropolitan         495.026538
# Northern Victoria               0.000000
# South-Eastern Metropolitan    357.864865
# Southern Metropolitan         466.380245
# Western Metropolitan          557.637232
# Western Victoria                0.000000
# Name: (mean, unit), dtype: float64

# %%
mask = pivot['mean']['house'] < pivot['median']['house']
filtered_pivot = pivot[mask]
display(filtered_pivot)
# Out:
#                       median                       mean              \
# Type                   house townhouse unit       house   townhouse
# Regionname
# Southern Metropolitan  586.0     246.0    0  569.643881  278.858824
# Western Metropolitan   531.0     198.0   62  507.883406  244.560669
#
#
# Type                         unit
# Regionname
# Southern Metropolitan  466.380245
# Western Metropolitan   557.637232

# %%
print(list(filtered_pivot.index))
# Out:
# ['Southern Metropolitan', 'Western Metropolitan']

# %%
import numpy as np
mser = pd.Series(
    np.random.rand(8),
    index=[['white','white','white','blue','blue','red','red','red'], 
           ['up','down','right','up','down','up','down','left']])
display(mser)
# Out:
# white  up       0.425611
#        down     0.413376
#        right    0.943702
# blue   up       0.855080
#        down     0.971863
# red    up       0.954963
#        down     0.594221
#        left     0.279091
# dtype: float64

# %%
print(mser.index)
# Out:
# MultiIndex([('white',    'up'),
#             ('white',  'down'),
#             ('white', 'right'),
#             ( 'blue',    'up'),
#             ( 'blue',  'down'),
#             (  'red',    'up'),
#             (  'red',  'down'),
#             (  'red',  'left')],
#            )

# %%
mframe = pd.DataFrame(
    np.random.randn(16).reshape(4,4),
    index=[['white','white','red','red'], ['up','down','up','down']],
    columns=[['pen','pen','paper','paper'],[1,2,1,2]]
)
display(mframe)
# Out:
#                  pen               paper
#                    1         2         1         2
# white up   -0.753570  0.088938  0.264992 -1.563918
#       down -1.862510  0.663200  1.712164  0.686350
# red   up   -1.687313 -0.728306  0.111831 -1.100295
#       down  1.185080  0.221861  1.834545 -1.467312

# %%
melb_df.groupby(['Type', 'Rooms'])['BuildingArea'].median().unstack()
# Out:
# Rooms         1      2      3      4      5      6      7      8      10
# Type
# house      126.0  126.0  126.0  141.0  177.0  126.0  216.5  126.0  126.0
# townhouse   88.0  114.0  126.0  159.5  152.0    NaN    NaN    NaN    NaN
# unit        69.5  110.0  126.0  126.0    NaN  171.0    NaN  126.0    NaN

# %%
mask13 = melb_df['Type'] == 'unit'
melb_df[mask13].groupby(['SellerG', 'Type'])['Price'].median().sort_values(ascending=False)
# Out:
# SellerG        Type
# Nick           unit         900000.0
# Marshall       unit         715000.0
# Cayzer         unit         707500.0
# Kay            unit         695000.0
# Noel           unit         693250.0
#                               ...
# YPA            townhouse         NaN
# hockingstuart  house             NaN
#                townhouse         NaN
# other          house             NaN
#                townhouse         NaN
# Name: Price, Length: 150, dtype: float64
